# %% [markdown]
# ### Przydatne dane

# %%
# 1. kombinacja klawiszy, ktore uruchmiają wszystkie kody to: shift + enter. Tu nie trzeba, tak jak w SQL zaznaczać całej linii, wystarczy, że kursor się tam znajdzie

# 2. Jak chcemy tworzyć komentarze, to tą linię, która ma być komentarzem, zaznaczamy jako 'Markdown' - opcja w pasku u góry. Już po zapisaniu komentarza, żeby go odpalić, muszę wcisnąć funkcję uruchmiającą: shift+enter

# 3. Jak chcemy dodać nową linię kodu, nie ciąg dalszy jakiejś konkretnej, ale całkiem nwoą, to najeżdzamy kursorem na przerwę miedzy dwoma osobnymi liniami kou i wtedy pojawia się 'Add Code Cell'(czyli linia kodu) albo 'Add Markdown cell', czyli komentarz

# %%
### Instalacja biblioteki MATPLOTLIB
# wchodzę do terminal -> wybieram command prompt -> wpisuje: pip install matplotlib

# %% [markdown]
# ### Import biblioteki Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Pierwszy wykres

# %%
plt.plot([0,1], [0,1]) # pierwszy nawias kwadratowy to [x1, x2], zas drugi to [y1, y2]

# %%
#pierwsza zmienna to punkt na osi x (od -1 do 1.1, o skoku 0.1, zas druga zmienna to punkty na osi y: x do potęgi 2
x = np.arange(-1,1.1, 0.1)
y = x ** 2

# %%
# teraz z tych danych robimy wykres
_ = plt.plot(x,y)

# %% [markdown]
# ### Tytuł wykresy

# %%
plt.plot(x,y)
_ = plt.title('Wykres x * x') # _ underscore to zmienna, do której przypisujemy dane wykresu - I ZAWSZE W PONIŻSZYCH WYKRESACH TAK BEDZIEMY ROBIĆ !!

# %% [markdown]
# ### Eksport takiegfo wykres

# %%
# prawym myszki najezdzam na dany wykres -> save as -> nazwa.png -> i teraz mogę już go wysyłać

# %% [markdown]
# ### Dwie funkcje na jednym wykresie

# %%
x1 = np.arange(-1, 1.1, 0.1) # punkty na osi x
y1 = x1 ** 3 # punkty na osi y

# %%
plt.plot (x,y) # teraz tworzymy wykres 1-ej fukncji
_ = plt.plot(x1, y1) # teraz tworzymy wykres 2-ej fukncji

# %% [markdown]
# ### Etykiety wykresów - zeby je rozróżnić

# %%
plt.plot (x,y, label='x^2') # label = legenda
plt.plot(x1, y1, label='x^3')
_ = plt.legend()

# %% [markdown]
# ### Wiele wykresów

# %%
plt.subplot(1, 2, 1) #subplot(1, 2, 1) = 1 wiersz, 2 kolumny, 1 wykres
plt.plot(x,y) # i teraz rysujemy wykres 1
plt.subplot(1,2,2) #subplot(1, 2, 1) = 1 wiersz, 2 kolumny, 2 wykres
_ = plt.plot (x1, y1) # i teraz rysujemy wykres 2

# %% [markdown]
# ### Wykres słupkowy

# %%
x2 = np.arange(1,6) #na osi damy liczby 1,2,3,4,5,
y2  = [10,20,40,15,99] #zas na osi y damy wartsoc 10,20,40,15, 99

# %%
_ = plt.bar(x2,y2) # teraz ten wykres rysujemy

# %% [markdown]
# ### Wykres rozproszony

# %%
xs = np.random.rand(500) # na osi x mamy 500 losowych wartości
ys = np.random.rand(500) # na osi y mamy 500 losowych wartości

# %%
_ = plt.scatter(xs, ys)

# %% [markdown]
# ### Histogram - czyli jak często występują dane wartości, które możemy gru[pować w kubełki (beans)

# %%
xh = np.random.randn(300)

# %%
_ = plt.hist(xh)

# %%
_ = plt.hist(xh, bins=15) # zmieniamy ilość punktów
